# %% [markdown]
# # Trabajo Final LP2
#
# ## Integrantes:
#
# - Poma Gómez Diego Alonso
# - Giancarlo Kuway
# - Manuel Mercedez

# %%
# Librerias a instalar 

#pip install pretty-html-table
#pip install selenium

# Descargar

# %%
# Ingresa producto y correo electrónico
producto= input("Ingrese el producto a comparar: ")
correo= input("Ingrese su dirección de correo electrónico (ej: example@gmail) ")
# Out:
# Ingrese el producto a comparar: yogurt
# Ingrese su dirección de correo electrónico (ej: example@gmail) di

# %% [markdown]
# # Metro
#
# ## Integrante:
# - Poma Gómez Diego Alonso

# %%
# PRUEBA FINAL (todos los productos de Metro)

# Se importan librerias
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import random
from time import sleep
from selenium.webdriver.chrome.service import Service

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s= Service('C:/Users/Diego/Desktop/Trabajo_Final_LP2/chromedriver.exe')   # Se utiliza comando Service() porque arrojaba error
                                                                          # deprecated .... iperkenel.
driver = webdriver.Chrome(service=s,options = options)

# Se asigna la pagina web a scrapear
driver.get("https://www.metro.pe/") 

# Da click para aceptar términos de un aviso emergente
WebDriverWait(driver, 5).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.swal2-confirm swal2-styled'.replace(' ','.')))).click()

# Selecciona y escribe el producto en el buscador Metro 
WebDriverWait(driver, 5).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'input#search-autocomplete-input'))).send_keys(producto)

# Click en 'Ver todos los resultados'
WebDriverWait(driver, 5).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'a.see-all'.replace(' ','.')))).click()

sleep(1)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")     # Hace scroll directo hacia el final de página
sleep(3)
WebDriverWait(driver, 120).until(
    EC.presence_of_all_elements_located((
        By.XPATH,'//div[@class="shelf-content"]/div[@style="display: none;"]')))  # Espera hasta que cargue la página

elementos= driver.find_elements(By.XPATH,'//li[@layout="19ccd66b-b568-43cb-a106-b52f9796f5cd"]')

datos1=[]
for elem in elementos:
    saco=[]
    try:
        precio= elem.find_element("xpath",'.//span[@class="product-prices__value product-prices__value--best-price"]').text
        nombre= elem.find_element("xpath",'.//a[@class="product-item__name"]').text
        print(nombre)
        print(precio)
        saco.append(nombre)
        saco.append(precio)
        datos1.append(saco)
    except:
        precio = 'NO DISPONIBLE'
        producto = 'NO DISPONIBLE'
# Out:
# Yogurt Battimix Gloria Vainilla C/Arroz Achocolatado Vaso 145 g
# S/3.40
# Yogurt Batido con Miel Gloria Griego 800g
# S/. 6.50
# Yogurt Griego Vakimu Original 1 Kg
# S/15.60
# Yogurt Frutado Danlac Fresa Botella 900 g
# S/10.90
# Yogurt Bebible Sabor Durazno Laive 1.8kg
# S/9.99
# Yogurt Parcialmente Descremado Gloria Durazno Galonera 1.7kg
# S/8.50
# Yogurt con Chocobolitas Cuisine & Co Yogurt! Choco Bolitas 125g
# S/2.39
# Yogurt con Grageas Cuisine & Co Yogurt! Gragea Mix 125g
# S/2.39
# Yogurt Bebible Sabor Vainilla Botella 1.9 Kg
# S/. 10.79
# Yogurt Bebible Sabor Fresa Botella 1.9 Kg
# S/. 10.79
# Yogurt Griego Mango con Fresa Pote 1 Kg
# S/15.60
# Yogurt Parcialmente Descremado Gloria Guanábana Galonera 1.7kg
# S/8.50
# Yogurt Parcialmente Descremado Sin Lactosa Fresa Gloria Botella 1 kg
# S/7.90
# Yogurt Bebible Sabor Durazno Laive Sbelt 1.8kg
# S/12.90
# Yogurt Bebible Sabor Lúcuma Laive 1kg
# S/. 6.49
# Yogurt Batishake Gloria Vainilla Vaso 120 g
# S/1.60
# Yogurt Descremado Edulcorado Fresa Slim Gloria Botella 1 kg
# S/6.80
# Yogurt
# S/3.00
# Alimento Lácteo Fermentado Sabor Fresa Laive 180g
# S/1.90
# Alimento Lácteo Vainilla Yofresh Botella 330 gr
# S/2.80
# Alimento Lácteo Fresa Yofresh Botella 330 gr
# S/2.80
# Alimento Lácteo Fresa Yofresh Botella 330 gr
# S/2.80
# Yopi Mix Hojuelas Laive 100g
# S/3.00
# Cuisinart Yogurtera/ Quesera Electrónica YM400E
# S/499.00
# Pack x4 Alimento Fermentado Vainilla Francesa Laive Bio Defensa 100ml
# S/5.50
# Pack x4 Alimento Fermentado Tutti Frutti Laive Bio Defensa Niños 100ml
# S/5.50
# Pack x4 Alimento Fermentado Fresa Laive Bio Defensa Light 100ml
# S/5.50
# Pack x4 Alimento Fermentado Uva Mora Laive Bio Defensa Niños 100ml
# S/5.50
# Pack x4 Alimento Fermentado Vainilla Laive Bio Defensa Light 100ml
# S/5.50
# Pack x4 Alimento Fermentado Fresa Laive Bio Defensa 100ml
# S/5.50

# %%
# LIMPIEZA Y ESTRUCTURACIÓN DE DATOS DESCARGADOS (METRO)

# Se crea la columna Cantidad
# Se importan librerias
import re
import pandas as pd

total1=[]
saco1=[]      # Nombre y Precio
saco2=[]      # Cantidad

for i in total_datos:
    saco1=[]   # nombre-precio-cantidad
    saco2=[]   # cantidad
    saco3=[]   # Agrupa los datos de cada producto
    saco1.append(i[0])
    for e in i:
        if e==i[0]:
            x= re.findall('\sx\s',e)    # Posee letra _x_ ?
            y= re.findall('[Pp]ack',e) # Posee palabra P-pack en el texto ?
            z= re.findall('^Mix',e)     # Posee letra Mix al comienzo ?
            w=re.findall('\sx.+',e)
            o= re.findall('\s[/]\s',e)
            u= re.findall('\s[+]\s',e)
            q=re.findall('\d.+',e)
            oq=re.findall('\d+',e)
            if len(y)>0:
                saco2.append('Pack') #se almacena pack como cantidad
            elif len(z)>0:
                saco2.append('Mix') # se almacena Mix como cantidad

            elif len(x)>0:
                if len(w)>0:
                    saco2.append(w[0])

            elif len(x)==0:
                if len(oq)==0:
                    if len(u)>0:
                        saco2.append('Duo')
                    else:
                        saco2.append('1 unidad')
                elif len(o)>0:
                    saco2.append(q[0])
                elif len(u)==0:
                    v=re.findall('\d+\s+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)',e)
                    v1=re.findall('\d+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)',e)
                    # v y v1 sirven para encontrar condiciones en la oracion 'e'
                    if len(oq)>=2:
                        t2=re.findall('%',e)
                        lp=e.split()
                        a=0
                        for elem in lp:
                            t=re.findall('^\d.+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)$',elem)
                            t1=re.findall('^([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)$',elem)

                            if len(t)==1:
                                saco2.append(lp[a])
                            elif len(t1)==1:
                                saco2.append(lp[a-1]+' '+lp[a])
                            a=a+1
                    else:
                        saco2.append(q[0])
                        
                    if len(v)==0 or len(v1)==0:
                        saco2.append(q[0])
                    
                elif len(u)>0:
                    saco2.append('Pack')
            else:
                saco2.append(q[0])
            
            if saco2[0]=='Pack' or saco2[0]=='Mix':
                saco3.append('Metro')
                saco3.append(saco1[0])
            else:
                saco1=saco1[0].replace(saco2[0],'')
                saco3.append('Metro')
                saco3.append(saco1)
                
        elif e==i[1]:
            e=e.split()
            for q in e:
                z=re.findall('\d.+',q)
                if len(z)>0:
                    saco3.append(z[0])
            
    saco3.append(saco2[0])
    total1.append(saco3)        

## Longitud de los datos
# len(total1

# Se crea dataframe para estructurar datos con las columnas Nombre-Precio(S/.)-Cantidad

columnas=['Local','Nombre','Precio','Cantidad']
Metro=pd.DataFrame(data=total1,columns=columnas)           

driver.close()
Metro
# Out:
#      Local                                             Nombre Precio Cantidad
# 0    Metro  Yogurt Battimix Gloria Vainilla C/Arroz Achoco...   3.40    145 g
# 1    Metro              Yogurt Batido con Miel Gloria Griego    6.50     800g
# 2    Metro                     Yogurt Griego Vakimu Original   15.60     1 Kg
# 3    Metro               Yogurt Frutado Danlac Fresa Botella   10.90    900 g
# 4    Metro                Yogurt Bebible Sabor Durazno Laive    9.99    1.8kg
# ..     ...                                                ...    ...      ...
# 184  Metro  Pack x4 Alimento Fermentado Tutti Frutti Laive...   5.50     Pack
# 185  Metro  Pack x4 Alimento Fermentado Fresa Laive Bio De...   5.50     Pack
# 186  Metro  Pack x4 Alimento Fermentado Uva Mora Laive Bio...   5.50     Pack
# 187  Metro  Pack x4 Alimento Fermentado Vainilla Laive Bio...   5.50     Pack
# 188  Metro  Pack x4 Alimento Fermentado Fresa Laive Bio De...   5.50     Pack
#
# [189 rows x 4 columns]

# %% [markdown]
# # Tottus
#
# ## Integrante:
#
# - Manuel Mercedez

# %%
# PRUEBA FINAL (todos los productos de Tottus)

# Se importan librerias
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import random
from time import sleep
from selenium.webdriver.chrome.service import Service

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s= Service('C:/Users/Diego/Desktop/Trabajo_Final_LP2/chromedriver.exe')   # Se utiliza comando Service() porque arrojaba error
                                                                          # deprecated .... iperkenel.
driver = webdriver.Chrome(service=s,options = options)

# Se asigna la pagina web a scrapear
driver.get("https://www.tottus.com.pe/") 

# Selecciona y escribe el producto en el buscador Tottus 
try:
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#catalystSearchBar'))).click()
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#inputSearchBar'))).send_keys('yogurt')
    #sleep(1)
    WebDriverWait(driver, 2).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.jsx-2851002401 searchIcon'.replace(' ','.')))).click()
except:
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input.jsx-3290144217 desktopSearchBar'.replace(' ','.')))).send_keys(producto)
    WebDriverWait(driver, 2).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.jsx-3290144217 searchIcon'.replace(' ','.')))).click()


datos3=[]

while True:
    WebDriverWait(driver, 10).until(
        EC.presence_of_all_elements_located((By.XPATH,'//li[@class="product"]')))
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")    
    sleep(1)

    elementos=driver.find_elements(By.XPATH,'//li[@class="product"]')
    for elem in elementos:
        saco=[]
        try:
            nombre= elem.find_element("xpath",'.//h2[@class="jsx-369422875 name title mini"]').text
            precio= elem.find_element("xpath",'.//span[@class="list price medium cmrPrice "]').text
            cantidad= elem.find_element("xpath",'.//h3[@class="jsx-369422875 extra text descriptive"]').text
            print(nombre)
            print(precio)
            print(cantidad)
            saco.append(nombre)
            saco.append(precio)
            saco.append(cantidad)
            datos3.append(saco)
        except:
            precio = 'NO DISPONIBLE'
            producto = 'NO DISPONIBLE'

    driver.execute_script("window.scrollBy(0, -800);")
    sleep(1)
    try:
        WebDriverWait(driver, 1).until(
            EC.element_to_be_clickable((By.XPATH,'//li[@class="next"]'))).click()
        sleep(2)
    except:
        break
# Out:
# YOGURT DESCREMADA GLORIA FRESA 1.7 KG
# s/ 10.5 UN
# YOGURT DESCREMADA GLORIA VAINILLA FRANCESA 1.7 KG
# s/ 10.5 UN
# YOGURT DESCREMADA GLORIA DURAZNO 1.7 KG
# s/ 10.5 UN
# YOGURT GRIEGO GLORIA NATURAL 120 GR
# s/ 2 UN
# SIX PACK YOGURT FRESA FRESA YOMOST 180 ML
# s/ 12 UN
# YOGURT MANGO
# s/ 6.5 UN
# YOGURT GRIEGO
# s/ 12.9 UN
# YOGURT GLORIA DURAZNO 1 KG
# s/ 6.55 UN
# YOGURT GLORIA LUCUMA 1 KG
# s/ 6.55 UN
# YOGURT GLORIA GUANABANA 1 KG
# s/ 6.55 UN
# YOGURT GLORIA FRESA 1 KG
# s/ 6.55 UN
# YOGURT GLORIA TUTTIFRUTTI 1 KG
# s/ 6.55 UN
# YOGURT GLORIA VAINILLA 1 KG
# s/ 6.55 UN
# YOGURT PROBIOTICO NATURAL
# s/ 6.5 UN
# YOGURT PROBIOTICO DURAZNO
# s/ 6.5 UN
# YOGURT PROBIOTICO FRESA
# s/ 6.5 UN
# YOGURT SABOR NATURAL
# s/ 11.5 UN
# YOGURT KIDS FRESA
# s/ 1.9 UN
# YOGURT PREMIUM NATURAL
# s/ 4.2 UN
# YOGURT FRUTADO FRESA
# s/ 4.9 UN
# YOGURT FRUTOS DE BOSQUE
# s/ 4.9 UN
# YOGURT FRUTADO AGUAYMANTO
# s/ 4.9 UN
# YOGURT PROBIOTICO GUANABANA
# s/ 6.5 UN
# YOGURT PROBIOTICO MORA
# s/ 6.5 UN
# YOGURT GRIEGO NATURAL
# s/ 5.5 UN
# YOGURT PERSONAL DURAZNO
# s/ 3 UN
# YOGURT PERSONAL FRESA
# s/ 3 UN
# YOGURT PERSONAL VAINILLA
# s/ 3 UN
# YOGURT SIN LACTOSA PROBIOTICO
# s/ 6.9 UN
# YOGURT PROBIOTICO DURAZNO
# s/ 9.95 UN
# YOGURT GLORIA FRUTADO FRESA 120 GR
# s/ 1.9 UN
# BATTISHAK GLORIA YOGURT E VAINILLA BAKUGAN
# s/ 1.65 UN
# YOGURT DESCREMADO FRUTADO FRESA DANLAC
# s/ 11.5 UN
# YOGURT DESCREMADA GLORIA SLIM BEBIBLE FRESA 1.7 KG
# s/ 10.8 UN
# YOGURT GLORIA BATTISHAKE FRESA MASHA Y EL OSO
# s/ 1.65 UN
# YOGURT GLORIA BATTIMIX VAINILLA CON BOLITAS DE CHOCOLATE
# s/ 3.4 UN
# YOGURT GLORIA BATTIMIX FRESA CON BOLITAS DE CHOCOLATE
# s/ 3.4 UN
# MANTEQUILLA GLORIA 90 GR
# s/ 5.9 UN
# MANTY PLUS MARGARINA 200 GR
# s/ 4.9 UN
# MANTEQUILL CON SAL
# s/ 15.9 UN
# MANTY PLUS MARGARINA 400 GR
# s/ 8.4 UN
# MANTEQUILLA CON SAL DANLAC
# s/ 13.9 UN
# MARGARINA SELLO DE ORO 200 GR
# s/ 4.2 UN
# MARGARINA SELLO DE ORO 400 GR
# s/ 7.9 UN
# MARGARINA SELLO DE ORO 200 GR
# s/ 4.6 UN
# MANTEQUILLA GLORIA POTE 390 GR
# s/ 17.9 UN
# MARGARINA ESPARCIBLE SELLO DE ORO 90 GR
# s/ 2.7 UN
# MANTEQUILLA GLORIA 200 GR
# s/ 10.4 UN
# MARGARINA DORINA CLASICA POTE X 500G
# s/ 10.6 UN
# MARGARINA DORINA LIGHT POTE X 500G
# s/ 10.6 UN
# MARGARINA UNTABLE
# s/ 3.7 UN
# MARGARINA UNTABLE TOTTUS
# s/ 5.95 UN
# QUESO FRESCO LIGHT
# s/ 32.9 KG
# QUESO FRESCO TOTTUS KG
# s/ 30.9 KG
# GLORIA QUESO CREMA BARRA
# s/ 11.9 UN
# DIP CABANOSSI DELICE
# s/ 12.9 UN
# QUESO SUIZO X KG
# s/ 52.9 KG
# QUESO UNTADELLI ACEITUNAS
# s/ 3.1 UN
# QUESO CAMBOZOLA GOURMET CREAMY Y BLUE
# s/ 19.9 UN
# QUESO UNTADELLI NATURAL
# s/ 3.1 UN
# QUESO PARMESANO
# s/ 64.5 KG
# QUESO PARIA CON OREGANO X KG
# s/ 47.9 KG
# QUESO TIPO CHIQUIAN
# s/ 56.9 KG
# QUESO CR GOU CABANOS CHIMICHURRI
# s/ 18.9 UN
# QUESO FRESCO DESLACTOSADO EMPACADO
# s/ 32.9 KG
# QUESO CABANA
# s/ 11.5 UN
# QUESO TIPO GRUYERE EL ARTESANO DE ANTANO X KG
# s/ 57.9 KG
# QUESO DE ESPINACA Y TOCINO
# s/ 18.9 UN
# QUESO CREMA LIGHT
# s/ 11.3 UN
# QUESO FRESCO MOLDE GRANDE
# s/ 35.5 KG
# QUESO VACA TIPO FETA FITAKI X 500 G
# s/ 59.9 UN
# QUESO PARIA DE VACA
# s/ 60 KG
# QUESO CREMA LIGHT NATURAL
# s/ 14.6 UN
# QUESO FRESCO
# s/ 35.9 KG
# QUESO FRESCO SIN LACTOSA LAIVE PORCION
# s/ 35.9 KG
# QUESO FUNDIDO UNTABLE
# s/ 3.2 UN
# QUESO FRESCO
# s/ 32.9 KG
# QUESO FRESCO ARTESANAL LAIVE PORCION X KG
# s/ 35.9 KG
# QUESO PARMESANO
# s/ 4.9 UN
# QUESO FRESCO SBELT X KG
# s/ 35.9 KG
# QUESO FRESCO BONLE MOLDE GRANDE POR KG
# s/ 32.9 KG
# QUESO FRESCO DE CABRA
# s/ 59.9 KG
# CREMA DE QUESO AHUMADO ERU 100G
# s/ 12.9 UN
# QUESO PARMESANO RALLADO
# s/ 4.9 UN
# CREAM CHEESE
# s/ 11.9 UN
# QUESO FRESCO
# s/ 36.9 KG
# QUESO DE VACA FRESCO
# s/ 49.9 KG
# QUESO FRESCO SBELT
# s/ 36.9 KG
# QUESO MOZARELLA SBELT
# s/ 14 UN
# QUESO FUNDIDO 08 TAJ
# s/ 6.2 UN
# QUESO SUIZO GRUYERE EMMI KG
# s/ 290 KG
# QUESO GORGONZOLA DOLCE PERLA VTA AL PESO
# s/ 119.9 KG
# QUESO PROVOLONE DOLCE PERLA VTA AL PESO
# s/ 105 KG
# QUESO MOZZARELLA RALLADO PREMIUM
# s/ 14.9 UN
# QUESO CHEDDAR FIELDS KG
# s/ 99.9 KG
# QUESO CREMA
# s/ 18.9 UN
# QUESO FUNDIDO
# s/ 11.3 UN
# QUESO EDAM
# s/ 12.5 UN
# QUESO DURO PECORINO ZANETTI 200 GR
# s/ 44.9 UN
# QUESO GRANA PADANO PARMAREGGIO 150GR
# s/ 26.5 UN
# CREMA DE QUESO GRUYERE ERU 100G
# s/ 12.9 UN
# CREMA DE QUESO MAASDAM ERU 100G
# s/ 12.9 UN
# QUESO CHEDDAR ROJO COBUGER VENTA AL PESO
# s/ 115 KG
# QUESO MADURADO EN ACEITE VIRGEN EL PASTOR 200 GR
# s/ 14.9 UN
# QUESO PARMIGIANO REGULAR PARMAREGGIO 150G
# s/ 34.9 UN
# QUESO CREMA NATURAL
# s/ 2.7 UN
# QUESO BOCCONCINI
# s/ 20.9 UN
# QUESO EDAM
# s/ 10.1 UN
# QUESO CAMEMBERT PRESTIGE 125 GR
# s/ 19.9 UN
# QUESO CREMA
# s/ 10.9 UN
# QUESO BRIETTE CREAMY AND BUTTERY RED X 125 G
# s/ 19.9 UN
# MOZARELLA
# s/ 11.5 UN
# CREMA DE QUESO GOUDA ERU 100G
# s/ 12.9 UN
# QUESO CAMEMBERT DANES
# s/ 16.9 UN
# QUESO PROVOLONE KG
# s/ 115.9 KG
# QUESO DANISH BLUE CHEESE KARAVEL KG
# s/ 99.9 KG
# QUESO PETIT BRIE AU BLEU ILE DE FRANCE 125 GR
# s/ 22.9 UN
# QUESO GORGONZOLA IGOR KG
# s/ 119.9 KG
# QUESO SUIZO EMMENTAL EMMI KG
# s/ 250 KG
# QUESO OVEJA CURADO AHUMADO EL PASTOR 150 GR
# s/ 12.9 UN
# QUESO MEZCLA SEMICURADO EL PASTOR 150 GR
# s/ 9.9 UN
# RULO CABRA CON PIMIENTA EL PASTOR 110 GR
# s/ 9.9 UN
# QUESO DE MEZCLA TIERNO EL PASTOR 150 GR
# s/ 9.9 UN
# RULO CABRA NATURAL EL PASTOR 110 GR
# s/ 9.9 UN
# RULO CABRA CON PLANTAS AROMATICAS EL PASTOR 110 GR
# s/ 9.9 UN
# QUESO MOZZARELLA BOLA
# s/ 10.3 UN
# QUESO DE OVEJA BOLETUS
# s/ 24.9 UN
# QUESO PARMESANO REGGIANO ZANETTI 150 GR
# s/ 37.9 UN
# MANCHEGO SEMICURADO PARAJE
# s/ 15.9 UN
# QUESO PARMESANO GRANULADO TOTTUS 454 GR
# s/ 25.9 UN
# QUESO CREMA
# s/ 9.5 UN
# RULO CABRA CON MIEL EL PASTOR 110 GR
# s/ 9.9 UN
# QUESO MANCHEGO ARTESANO CURADO DEHESA 235 GR
# s/ 34.9 UN
# QUESO MANCHEGO ARTESANO MEDIA CURACION DEHESA 250 GR
# s/ 34.9 UN
# QUESO DE OVEJA TRUFADO CURADO VEGA SOTUELAMOS 200 GR
# s/ 29.9 UN
# QUESO DE OVEJA CON ACEITUNA NEGRA VEGA SOTUELAMO 200 GR
# s/ 29.9 UN
# QUESO DE OVEJA CON AJO NEGRO VEGA SOTUELAMOS 200 GR
# s/ 29.9 UN
# QUESO MOZZARELLA LIGHT 200 G
# s/ 10.9 UN
# QUESO EDAM LIGHT
# s/ 10.9 UN
# QUESO MOZZARELLA
# s/ 10.9 UN
# QUESO EDAM
# s/ 10.9 UN
# QUESO GOUDA
# s/ 10.9 UN
# MEZCLA YOGURT MIX 180 GR
# s/ 11 UN
# FOUR PACK FRESA LIGHT PREMIUM
# s/ 14.9 UN
# BIODEFENSA VAINILLA FRANCESA ZERO
# s/ 6.2 UN
# BIODEFENSA FRESA
# s/ 6.2 UN
# BIODEFENSA VAINILLA FRANCESA
# s/ 6.2 UN
# BIODEFENSA FRESA/FRAMBUESA ZERO
# s/ 6.2 UN
# BIODEFENSA KIDS LAIVE UVA MORA
# s/ 6.2 UN
# BIODEFENSA KIDS LAIVE TUTTI FRUTI
# s/ 6.2 UN
# YOGURTMIX LAIVE VNLL CHOCOLATE
# s/ 3.5 UN
# QUESO GOUDA EL ARTESANO X KG
# s/ 56.9 KG
# QUESO ANDINO
# s/ 56.9 KG
# QUESO GORGONZOLA PICCANTE VENTA AL PESO
# s/ 139.9 KG
# QUESO MADURADO GOUDA X KG
# s/ 51.9 KG
# PARMIGIANO REGGIANO BIO
# s/ 39.9 UN
# QUESO MADURADO ALTARTUFO MARENCHINO KG
# s/ 140 KG
# QUESO MEZCLA CURADO EL PASTOR KG
# s/ 59 KG
# QUESO MASCARPONE
# s/ 24.9 UN
# QUESO MADURADO MAASDAM VELDHUYZEN KG
# s/ 49 KG
# QUESO GORGONZOLA PICANTE IGOR KG
# s/ 149.9 KG
# QUESO MADURADO CON TRUFA BASIRON 200 GR
# s/ 29.9 UN
# QUESO MADURADO CON NUEZ BASIRON WALNUT 200 GR
# s/ 29.9 UN
# QUESO MADURADO DE CABRA
# s/ 19.9 UN
# QUESO MADURADO PESTO VERDE BASIRON 200 GR
# s/ 29.9 UN
# QUESO MADURADO MONTANA INTENSO 200 GR
# s/ 21.9 UN
# HELADO DE COCO Y MASA DE GALLETA
# s/ 39.9 UN
# HELADO CON CARAMELO Y SAL MARINA HALO TOP ICE CREAM 473 ML
# s/ 32.9 UN
# HELADO CON CREMA DE MANI 473 ML
# s/ 32.9 UN
# HELADO CON CHOCOLATE 473 ML
# s/ 32.9 UN
# HELADO CON GALLETAS SABOR CHOCOLATE 47
# s/ 32.9 UN
# CHOCO YOGURT CEREAL BAÑADO CON CHOCOLATE 2 CERRITOS 350 GR
# s/ 15.5 UN
# JABON LIQUIDO PEPINO Y YOGURT
# s/ 8.5 UN
# MÁQUINA DE YOGUR 20W BLANCO BYMP048
# s/ 99 UN
# YOGURT DESCREMADA PIAMONTE LÚCUMA 946 ML
# s/ 8.4 UN
# MARGARINA DORINA CLÁSICA 1 KG
# s/ 19.9 UN

# %%
# LIMPIEZA Y ESTRUCTURACIÓN DE DATOS DESCARGADOS (Tottus)

# Se importan librerias
import re
import pandas as pd

total3=[]

for i in datos3:
    saco1=[]   # nombre-precio-cantidad
    saco1.append('Tottus')
    for e in i:
        if e==i[0]:
            saco1.append(e)
        if e==i[1]:
            e=e.split()
            for q in e:
                z=re.findall('\d.+',q)
                z1=re.findall('\d+',q)
                if len(z)>0: 
                    saco1.append(z[0])
                elif len(z1)>0:
                    saco1.append(z1[0])
        if e==i[2]:
            saco1.append(e)

    total3.append(saco1)        

# Se crea dataframe con datos ya estructurados con las columnas Nombre-Precio(S/.)-Cantidad

columnas=['Local','Nombre','Precio','Cantidad']
Tottus=pd.DataFrame(data=total3,columns=columnas)           
Tottus
# Out:
#       Local                                             Nombre Precio  \
# 0    Tottus              YOGURT DESCREMADA GLORIA FRESA 1.7 KG   10.5
# 1    Tottus  YOGURT DESCREMADA GLORIA VAINILLA FRANCESA 1.7 KG   10.5
# 2    Tottus            YOGURT DESCREMADA GLORIA DURAZNO 1.7 KG   10.5
# 3    Tottus                YOGURT GRIEGO GLORIA NATURAL 120 GR      2
# 4    Tottus          SIX PACK YOGURT FRESA FRESA YOMOST 180 ML     12
# ..      ...                                                ...    ...
# 258  Tottus  CHOCO YOGURT CEREAL BAÑADO CON CHOCOLATE 2 CER...   15.5
# 259  Tottus                      JABON LIQUIDO PEPINO Y YOGURT    8.5
# 260  Tottus                MÁQUINA DE YOGUR 20W BLANCO BYMP048     99
# 261  Tottus           YOGURT DESCREMADA PIAMONTE LÚCUMA 946 ML    8.4
# 262  Tottus                      MARGARINA DORINA CLÁSICA 1 KG   19.9
#
#                        Cantidad
# 0        GLORIA - ENVASE 1.7 KG
# 1        GLORIA - ENVASE 1.7 KG
# 2        GLORIA - ENVASE 1.7 KG
# 3        GLORIA - ENVASE 120 GR
# 4        YO-MOST - PAQUETE 6 UN
# ..                          ...
# 258    2-CERRITOS - CAJA 350 GR
# 259      TOTTUS - FRASCO 400 GR
# 260  BLANIK - MAQUINA DE YOGURT
# 261    PIAMONTE - ENVASE 946 ML
# 262        DORINA - ENVASE 1 KG
#
# [263 rows x 4 columns]
