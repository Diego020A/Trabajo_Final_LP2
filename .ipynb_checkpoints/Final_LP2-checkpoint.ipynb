# %% [markdown]
# # Trabajo Final LP2
#
# ## Integrantes:
# - Poma Gómez Diego Alonso
# -
# -

# %%
import requests
from bs4 import BeautifulSoup

url =

# %%
from selenium import webdriver
import random
from time import sleep
from selenium.webdriver.chrome.service import Service

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s= Service('C:/Users/Diego/Desktop/Trabajo_Final_LP2/chromedriver.exe')   # Se utiliza comando Service() porque arrojaba error
                                                                          # deprecated .... iperkenel.
driver = webdriver.Chrome(service=s,options = options)

driver.get("https://www.metro.pe/")  

#confirmacion= driver.find_element("xpath",'//button[@class="swa12-confirm swa12-styled"]')
#confirmacion.click()

boton=driver.find_element("xpath",'//button[@class="btn red toggle-menu"]')
boton.click()
sleep(3)

frutas= driver.find_element("xpath",'//div[@class="item frutas-y-verduras"]')
frutas.click()

sleep(5)
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
sleep(15)

frutas_elem= driver.find_elements("xpath",'//li[@class="frutas-y-verduras"]')

sleep(5)

for fruta in frutas_elem:
    try:
        precio= fruta.find_element("xpath",'.//span[@class="product-prices__value product-prices__value--best-price"]').text
        print(precio)
        producto= fruta.find_element("xpath",'.//a[@class="product-item__name"]').text
        print(producto)
    except:
        break
# Out:
# S/. 3.49
# Tomate Italiano Metro x kg
# S/. 2.99
# Mandarina Costa Metro x kg
# S/. 4.99
# Cebolla Roja Metro x kg
# S/. 3.99
# Papa Canchán Procesada Especial x kg
# S/. 5.99
# Zanahoria Especial x kg
# S/. 2.69
# Zapallo Macre x kg
# S/. 3.49
# Plátano Isla Metro x kg
# S/. 2.90
# Apio x Atado Cuisine & Co
# S/. 5.29
# Papaya Metro x kg
# S/. 7.99
# Brócoli Metro x kg
# S/. 2.49
# Tangelo sin Pepa Metro x kg
# S/. 5.99
# Papa Amarilla Peruanita Procesada Metro x kg
# S/. 3.59
# Papa Blanca x kg
# S/. 2.69
# Camote Amarillo Metro x kg
# S/. 2.50
# Choclo Especial x unid
# S/. 2.69
# Plátano de Seda Metro x kg
# S/7.59 x kg
# Ají Amarillo x kg
# S/12.79 x kg
# Pimiento Metro x kg
# S/1.69
# Pepinillo x un
# S/0.99
# Perejil x atado
# S/2.99
# Albahaca x atado
# S/1.99
# Lechuga Crespa Cuisine & Co 320g
# S/7.59 x kg
# Fresa Americana Metro x kg
# S/3.49 x kg
# Camote Morado Metro x kg
# S/7.99 x kg
# Ajos sin Pelar x kg
# S/6.35 x kg
# Piña Golden Metro x kg
# S/2.99 x kg
# Manzana Delicia Kinder x kg
# S/2.79 x kg
# Melón Coquito Metro x kg
# S/7.49 x kg
# Vainita Metro x kg
# S/7.99 x kg
# Kión Metro x kg
# S/6.49 x kg
# Arveja x kg
# S/2.19
# Lechuga Americana Metro x unid
# S/0.89
# Granadilla Especial x unid
# S/1.99 x kg
# Piña para Jugo x kg
# S/3.99 x kg
# Papa Amarilla Peruanita Cocktail x kg
# S/6.80
# Champiñones Enteros Paccu Bandeja 200g
# S/7.99 x kg
# Espinaca x kg
# S/3.19
# Cebolla China x atado
# S/4.39
# Beterraga x atado
# S/4.99 x kg
# Plátano Bizcocho Tipo Exportación x kg
# S/4.49 x kg
# Plátano de Seda Tipo Exportación x kg
# S/6.99 x kg
# Manzana Royal Gala x kg
# S/6.99 x kg
# Manzana Roja x kg
# S/1.19
# Culantro x atado
# S/13.99
# Arándano Blueberry 500 g
# S/14.99 x kg
# Palta Madura Cremosita x kg
# S/4.99 x kg
# Naranja de Mesa Sin Pepa Metro x kg
# S/. 6.10
# Espinaca Baby Ecologic 150g
# S/. 7.60
# Espinaca Hidropónica de Invernadero Ecologic 500g
# S/8.49 x kg
# Chirimoya Metro x kg
# S/3.49 x kg
# Plátano Bellaco x kg
# S/4.99 x kg
# Papa Huayro Metro x kg
# S/8.49 x kg
# Olluco Metro x kg
# S/5.49 x kg
# Manzana Rayada Metro x kg
# S/6.99 x kg
# Mango Edward Metro x kg
# S/11.49 x kg
# Melocotón x kg
# S/4.49 x kg
# Cebolla Roja Campo Lindo x kg
# S/4.39 x kg
# Yuca x kg
# S/2.99
# Media Col Corazón
# S/. 1.90
# Lechuga Hidropónica Don Miguel x unid
# S/2.79
# Poro x un
# S/5.49
# Coliflor x un
# S/4.49
# Aguaymanto Fresco Pelado Emporio 200g
# S/6.99
# Uva Negra Sin Semilla 900g
# S/6.80
# Champiñones Picados Paccu 200g
# S/7.99
# Espárragos Atado 250g
# S/. 3.60
# Mix de Lechuga Crespa Ecologic x 2 Unid
# S/. 10.30
# Papa Amarilla Tumbay Agro Selecto 1Kg
# S/. 5.00
# Papa Huayro Agro Selecto 1Kg
# S/. 5.30
# Papa Huamantanga Agro Selecto 1Kg
# S/. 5.90
# Papa Yungay Agro Selecto 1Kg
# S/. 4.80
# Camote Morado Agro Selecto 1Kg
# S/. 3.70
# Camote Amarillo Agro Selecto 1Kg
# S/. 6.20
# Cebolla Roja Agro Selecto 1Kg
# S/. 2.80
# Lechuga Hoja de Roble Verde Hidropónica Ecologic x unid
# S/. 2.90
# Lechuga Crespa Hidropónica de Invernadero Ecologic x unid
# S/. 4.40
# Pepino Holandés Hidropónico de Invernadero Ecologic x unid
# S/. 9.60
# Pimiento de Colores Ecologic 3un
# S/6.50
# Champiñones Enteros Metro Bandeja 200g
# S/15.79 x kg
# Rocoto Metro x kg
# S/3.49
# Mix para Emoliente
# S/27.00 x kg
# Pasas Morenas x kg
# S/5.99 x kg
# Palta Super Fuerte x kg
# S/. 14.50
# Maíz Morado Campo Lindo x kg
# S/. 6.90
# Cebolla Blanca Campo Lindo x kg
# S/1.99 x kg
# Papa Blanca Cocktail x kg
# S/4.99 x kg
# Nabo x kg
# S/0.99
# Hierba Buena x atado
# S/3.99
# Zapallito Italiano x un
# S/4.99 x kg
# Plátano Palillo x kg
# S/9.40
# Olluco Picado Cuisine & Co 600g
# S/12.30
# Verduras Picadas para Menestrón Cuisine & Co 700g
# S/. 3.20
# Apio en Bastones Ecologic 200 g
# S/4.99
# Ciruelillo 600g
# S/. 5.60
# Vainita Justo al Día 700g
# S/. 5.70
# Papa Canchán Procesada Agro Selecto 1Kg
# S/. 12.00
# Cebolla Roja Agro Selecto 2Kg
# S/. 2.80
# Lechuga Roja Hidropónica de Invernadero Ecologic x unid
# S/12.49 x kg
# Ají Limo Metro x kg
# S/5.99 x kg
# Lima Metro x kg
# S/6.99 x kg
# Uva Vallet Metro x kg
# S/6.29 x kg
# Papa Amarilla Tumbay Especial Metro x kg
# S/9.99 x kg
# Membrillo x kg
# S/5.69 x kg
# Manzana Israel Añawi Metro x kg
# S/8.49 x kg
# Uva Red Globe Metro x kg
# S/6.99 x kg
# Carambola x kg
# S/7.99 x kg
# Uva Borgoña x kg
# S/0.89
# Huacatay x atado
# S/5.49 x kg
# Frijol Chino x kg
# S/2.19
# Berenjena x un
# S/5.99
# Granadilla Tipo Exportación 4un.
# S/11.90
# Verduras Picadas para Ensalada Mixta Cuisine & Co 600g
# S/9.40
# Verduras Picadas para Estofado de Carne Cuisine & Co 200g
# S/10.99
# Ajos Picados Mr.Ajo Pote 250 g
# S/. 6.90
# Papa Negra Andina Agro Selecto 1Kg
# S/. 7.60
# Tomate Saladette Hidropónico de Invernadero Ecologic Bolsa
# S/. 3.49
# Lechuga Romana Hidropónica de Invernadero Ecologic x unid
# S/. 5.40
# Pepinillo Pickles Hidropónico de Invernadero Ecologic Bandeja 300g
# S/. 6.20
# Zanahoria Baby Hidropónica de Invernadero Ecologic Bandeja 250g
# S/7.70
# Piña en Trozos Golden 350g
# S/9.99 x kg
# Holantao Metro x kg
# S/4.29
# Alcachofa con Espinas Metro x unid
# S/3.70
# Lechuga Morada Delisalad 300g
# S/32.00 x kg
# Maní Frito Salado x kg
# S/. 5.20
# Espinaca Bebé de Invernadero Don Miguel 150 g
# S/4.29 x kg
# Manzana Delicia Extra x kg
# S/3.19
# Lechuga Hidropónica x un
# S/3.30
# Lechuga Cultivada con Agua de Pozo La Caserita
# S/. 5.50
# Lechuga de Invernadero Oakleaf Don Miguel
# S/9.79
# Ajos Pelados Mr. Ajo 250g
# S/12.50
# Piña en Trozos Golden 500g
# S/8.70
# Verduras Picadas para Menestrón Cuisine & Co 300g
# S/7.90
# Verduras Picadas para Crema de Vegetales Cuisine & Co 350g
# S/8.00
# Verduras Picadas para Sopa de Verduras Cuisine & Co 300g
# S/11.30
# Verduras Picadas para Sopa de Verduras Cuisine & Co 600g
# S/10.70
# Verduras Picadas para Locro Cuisine & Co 700g
# S/12.50
# Arvejas Picadas Cuisine & Co 200g
# S/10.00
# Vainitas Picadas Cuisine & Co 500g
# S/4.90
# Bebida de Chicha Morada Golden Botella 485ml
# S/. 5.50
# Ensalada Parrillera Ecologic x 400 g
# S/. 8.80
# Papa Tricolor Cocktail Agro Selecto 800 g
# S/. 9.40
# Papa Peruanita Agro Selecto 1kg
# S/. 10.80
# Papa Canchán Procesada Agro Selecto 2Kg
# S/. 6.20
# Rabanito Baby Hidropónico de Invernadero Ecologic Bandeja 250g
# S/5.69
# Media Col China
# S/4.79
# Media Col Morada x un
# S/5.40
# Mix de Lechuga Cuisine & Co 200g
# S/8.60
# Pulpa de Ciruela Agroselva 250g
# S/8.70
# Verduras Picadas para Sopa Chake Cuisine & Co 350g
# S/11.50
# Verduras Picadas para Sopa Chake Cuisine & Co 700g
# S/10.40
# Verduras Picadas para Ensalada Sancochado Cuisine & Co 800g
# S/4.90
# Bebida de Chicha Morada Light Golden Botella 485ml
# S/35.90
# Néctar Tropical Bajo en Calorías Ecofresh Galón 3.8L
# S/35.90
# Néctar de Naranja Bajo en Calorías Ecofresh Galón 3.8L
# S/19.90
# Néctar de Tuna con Piña Bajo en Calorías Ecofresh Botella 1.8L
# S/19.90
# Néctar de Naranja con Zanahoria Bajo en Calorías Ecofresh 1.8L
# S/19.90
# Néctar Tropical Bajo en Calorías Ecofresh Botella 1.8L
# S/19.90
# Néctar de Naranja Bajo en Calorías Ecofresh Botella 1.8L
# S/11.50
# Néctar de Fresa con Naranja Bajo en Calorías Ecofresh Botella 1L
# S/14.90
# Néctar de Mandarina Bajo en Calorías Ecofresh Botella 1L
# S/11.50
# Néctar de Piña Bajo en Calorías Ecofresh Botella 1L
# S/11.50
# Néctar de Tuna con Piña Bajo en Calorías Ecofresh Botella 1L
# S/11.50
# Néctar de Naranja Bajo en Calorías Ecofresh Botella 1L
# S/4.59
# Papaya en Trozos Natifrut 180g
# S/4.40
# Berengena Hidropónica Ecológica x Unidad
# S/. 7.40
# Mix Col y Zanahoria Ecologic 250 g
# S/. 6.30
# Apio en Tallos Ecologic 400 g
# S/8.49
# Mix de Aguaymanto y Arándanos 300g
# S/8.49 x kg
# Mamey Metro x kg
# S/75.00 x kg
# Mix Nuts Premium x kg
# S/11.99
# Dátiles Deshidratados 200g
# S/. 6.90
# Tomate Cherry Hidropónico de Invernadero Don Miguel Bandeja 300 g
# S/. 12.20
# Pulpa de Kiwi Agroselva
# S/. 3.40
# Lechuga Crespa Hidropónica Manantiales x unid
# S/8.29
# Ajo Picado Mr. Ajo Bandeja 150 g
# S/. 12.90
# Ajos Enteros Justo al Día 700g
# S/. 16.60
# Rocoto Justo al Día 700g
# S/. 7.80
# Ají Amarillo Justo al Día 700g
# S/. 5.30
# Habas Justo al Día 700g
# S/. 5.20
# Zanahoria Justo al Día 700g
# S/. 6.40
# Arúgula Silvestre Ecologic 150 g
# S/. 10.00
# Papa Blanca Perricholi Procesada Agro Selecto
# S/12.49
# Puntas de Espárragos Paquete 250 g
# S/. 9.20
# Pula de Fresa Agroselva Doypack 250g
# S/21.00
# Dátiles Medjool El Dátil 300g
# S/. 9.20
# Pulpa de Tuna Agroselva Doypack 250g
# S/. 10.20
# Mezcla para Preparar Chicha Morada Campo Lindo 250g
# S/. 18.20
# Maíz Morado Campo Lindo 1kg
# S/. 2.60
# Lechuga de Seda Hidropónica Manantiales x unid
# S/45.00 x kg
# Mixtura de Frutas x kg
# S/19.90
# Jugo de Naranja Pasteurizada Ecofresh Botella 1.8L
# S/30.00 x kg
# Maní con Pasas x kg
# S/. 9.49
# Pulpa de Arándanos Agroselva Doypack 250g
# S/. 9.90
# Pulpa de Piña Golden Agroselva Doypack 250g
# S/. 9.20
# Pulpa de Melocotón Agroselva Doypack 250g
# S/. 12.20
# Pulpa de Granada Agroselva Doypack 250g
# S/4.60
# Agua de Piña Light Golden 485ml
# S/. 12.20
# Pulpa de Guanábana Agroselva Doypack 250g
# S/. 9.20
# Pulpa de Tamarindo Agroselva Doypack 250g
# S/12.49
# Dátiles Frescos El Dátil Bandeja 150 gr
# S/3.60
# Cebollita China Línea Verde x atado
# S/15.30
# Germinado de Brócoli Age Bandeja 100g
# S/13.70
# Mix de Germinados Age Bandeja 100g
# S/7.29
# Ajos Pelados Mr. Ajo Bandeja 150g
# S/10.00
# Ají Mirasol Despepitado Naturandes Bandeja 100g
# S/. 4.90
# Acelga Don Miguel 300g
# S/24.00 x kg
# Zapallo Loche x kg
# S/2.39
# Manzanilla x atado
# S/13.10
# Germinado de Alfalfa Age Bandeja 100g

# %%
#pip install webdriver-manager
# Out:
# Collecting webdriver-manager
#   Downloading webdriver_manager-3.8.2-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: requests in c:\users\diego\anaconda3\lib\site-packages (from webdriver-manager) (2.26.0)
# Collecting python-dotenv
#   Downloading python_dotenv-0.20.0-py3-none-any.whl (17 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\diego\anaconda3\lib\site-packages (from requests->webdriver-manager) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\diego\anaconda3\lib\site-packages (from requests->webdriver-manager) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\diego\anaconda3\lib\site-packages (from requests->webdriver-manager) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\diego\anaconda3\lib\site-packages (from requests->webdriver-manager) (3.2)
# Installing collected packages: python-dotenv, webdriver-manager
# Successfully installed python-dotenv-0.20.0 webdriver-manager-3.8.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# pip install selenium
a=["a","b","c","d","e","f","g"]

tipos=["frutas-y-verduras","carnes-aves-y-pescados","desayuno","lacteos","embutidos-y-fiambres",
       "abarrotes","aguas-y-bebidas"]
'//div[@class="item frutas-y-verduras",'tipos[0]']'
# Out:
#   File "C:\Users\Diego\AppData\Local\Temp/ipykernel_8024/2753168714.py", line 6
#     '//div[@class="item frutas-y-verduras",'tipos[0]']'
#                                             ^
# SyntaxError: invalid syntax
