# %% [markdown]
# # Trabajo Final LP2
#
# ## Integrantes:
#
# - Poma Gómez Diego Alonso
# - Giancarlo Kuway
# - Manuel Mercedez

# %%
# Librerias a instalar 

#pip install pretty-html-table
#pip install selenium

# Descargar
# Out:
# 'hola'

# %%
# Ingresa producto y correo electrónico
producto= input("Ingrese el producto a comparar: ")
correo= input("Ingrese su dirección de correo electrónico (ej: example@gmail) ")
# Out:
# Ingrese el producto a comparar: qwerqwr
# Ingrese su dirección de correo electrónico (ej: example@gmail) diego

# %% [markdown]
# # Metro
#
# ## Integrante:
# - Poma Gómez Diego Alonso

# %%
# PRUEBA FINAL (todos los productos de Metro)

# Se importan librerias
from selenium.webdriver.common.keys import Keys                  # Para cambiar el nombre de un producto inválido ingresado
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import random
from time import sleep
from selenium.webdriver.chrome.service import Service

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s= Service('C:/Users/Diego/Desktop/Trabajo_Final_LP2/chromedriver.exe')   # Se utiliza comando Service() porque arrojaba error
                                                                          # deprecated .... iperkenel.
driver = webdriver.Chrome(service=s,options = options)

# Se asigna la pagina web a scrapear
driver.get("https://www.metro.pe/") 

# Da click para aceptar términos de un aviso emergente
WebDriverWait(driver, 5).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.swal2-confirm swal2-styled'.replace(' ','.')))).click()

# Selecciona y escribe el producto en el buscador Metro 
WebDriverWait(driver, 5).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'input#search-autocomplete-input'))).send_keys(producto)

# %%
# Se verifica si el nombre del producto ingresado es válido

while True:
    try:
        # Click en 'Ver todos los resultados'
        WebDriverWait(driver, 2).until(
                EC.element_to_be_clickable((By.CSS_SELECTOR,'a.see-all'.replace(' ','.')))).click()
        break
    except:
        print("No se encontraron resultados, nombre de producto inválido")
        producto=input('Vuelva a ingresar el nombre de producto: ')
        # Se sombrea el texto del producto inválido
        WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#search-autocomplete-input'))).send_keys(Keys.CONTROL + 'a')
        sleep(1)
        # Se escribe el nuevo nombre de producto ingresado
        WebDriverWait(driver, 5).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#search-autocomplete-input'))).send_keys(producto)
# Out:
# No se encontraron resultados, nombre de producto inválido
# Vuelva a ingresar el nombre de producto: qwwweee
# No se encontraron resultados, nombre de producto inválido
# Vuelva a ingresar el nombre de producto: avena

# %%
# Hace scroll directo hacia el final de página
driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")     
sleep(2)
# Espera a que carguen todos los productos de la página
WebDriverWait(driver, 120).until(
    EC.presence_of_all_elements_located((
        By.XPATH,'//div[@class="shelf-content"]/div[@style="display: none;"]')))  

elementos= driver.find_elements(By.XPATH,'//li[@layout="19ccd66b-b568-43cb-a106-b52f9796f5cd"]')

datos1=[]
# Se extraen el nombre(junto con la cantidad) y el precio
for elem in elementos:
    saco=[]
    try:
        precio= elem.find_element("xpath",'.//span[@class="product-prices__value product-prices__value--best-price"]').text
        nombre= elem.find_element("xpath",'.//a[@class="product-item__name"]').text
        print(nombre)
        print(precio)
        saco.append(nombre)
        saco.append(precio)
        datos1.append(saco)
    except:
        precio = 'NO DISPONIBLE'
    saco1.append(i[0])
    for e in i:
        if e==i[0]:
            x= re.findall('\sx\s',e)    # Posee letra _x_ ?
            y= re.findall('[Pp]ack',e) # Posee palabra P-pack en el texto ?
            z= re.findall('^Mix',e)     # Posee letra Mix al comienzo ?
            w=re.findall('\sx.+',e)     # Coincide desde x_ hasta el final de la oración
            o= re.findall('\s[/]\s',e)  # Posee símbolo '/' 
            u= re.findall('\s[+]\s',e)  # Posee símbolo '+'
            q=re.findall('\d.+',e)      # Coincide con cualquier numero_ hasta el final de la oración
            oq=re.findall('\d+',e)      # Coincide con todos los números enteros
            if len(y)>0:
                saco2.append('Pack') #se almacena pack como cantidad
            elif len(z)>0:
                saco2.append('Mix') # se almacena Mix como cantidad

            elif len(x)>0:
                if len(w)>0:
                    saco2.append(w[0])

            elif len(x)==0:
                if len(oq)==0:
                    if len(u)>0:
                        saco2.append('Duo')
                    else:
                        saco2.append('1 unidad')
                elif len(o)>0:
                    saco2.append(q[0])
                elif len(u)==0:
                    v=re.findall('\d+\s+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)',e)
                    v1=re.findall('\d+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)',e)
                    # v y v1 sirven para encontrar condiciones en la oracion 'e'
                    if len(oq)>=2:
                        t2=re.findall('%',e)
                        lp=e.split()    # Separa la oración en palabras
                        a=0     # contador
                        for elem in lp:
                            t=re.findall('^\d.+([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)$',elem)
                            t1=re.findall('^([Mm]l|[Kk]g|g|[Uu]nid|[Ll]t|[Ll]|[Ss]obres|gr|[Uu]n\.|[Uu]nidades|Filtrantes|[Ll]itro|[Ll]itros|[Uu]n|[Oo]nzas)$',elem)

                            if len(t)==1:
                                saco2.append(lp[a])              # Si coincide, agregar a saco2
                            elif len(t1)==1:        
                                saco2.append(lp[a-1]+' '+lp[a])  # de lo contrario, juntarlo con el elemento anterior y agregarlo
                            a=a+1                                # a saco2
                    else:
                        saco2.append(q[0])
                        
                    if len(v)==0 or len(v1)==0:
                        saco2.append(q[0])
                    
                elif len(u)>0:
                    saco2.append('Pack')
            else:
                saco2.append(q[0])
            
            if saco2[0]=='Pack' or saco2[0]=='Mix':
                saco3.append('Metro')
                saco3.append(saco1[0])
            else:
                saco1=saco1[0].replace(saco2[0],'')
                saco3.append('Metro')
                saco3.append(saco1)
                
        elif e==i[1]:
            e=e.split()
            for q in e:
                z=re.findall('\d.+',q)
                if len(z)>0:
                    saco3.append(z[0])
            
    saco3.append(saco2[0])
    total1.append(saco3)        

## Longitud de los datos
# len(total1

# Se crea dataframe para estructurar datos con las columnas Nombre-Precio(S/.)-Cantidad

columnas=['Local','Nombre','Precio (S/.)','Cantidad']
Metro=pd.DataFrame(data=total1,columns=columnas)           

driver.close()
Metro
# Out:
#      Local                                             Nombre Precio (S/.)  \
# 0    Metro                      Avena Natural Santa Catalina         11.99
# 1    Metro                Avena Tradicional Cuisine&Co Bolsa          4.15
# 2    Metro  Avena Con Manzana Instantánea Santa Catalina B...         4.79
# 3    Metro              Avena con Algarrobina Santa Catalina          5.39
# 4    Metro                               Avena Cereal Andino          5.90
# ..     ...                                                ...          ...
# 113  Metro  Jabón Líquido para Manos 2 en 1 Avena & Miel B...         9.20
# 114  Metro    Cereal Mix Avena y Almendras Cuisine & Co Caja         11.90
# 115  Metro  Barras de Almendras, Hojuelas Avena y Frutos S...        31.90
# 116  Metro  Barras de Almendras, Hojuelas Avena y Frutos S...        31.90
# 117  Metro  Pack x6 Galletas Rellenas Casino Black Sabor C...         4.10
#
#     Cantidad
# 0       900g
# 1      300 g
# 2      150 g
# 3       280g
# 4      270 g
# ..       ...
# 113     Pack
# 114   380 gr
# 115     Pack
# 116     Pack
# 117     Pack
#
# [118 rows x 4 columns]

# %% [markdown]
# # Tottus

# %%
# PRUEBA FINAL (todos los productos de Tottus)

# Se importan librerias
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import random
from time import sleep
from selenium.webdriver.chrome.service import Service

options = webdriver.ChromeOptions()
options.add_argument('--incognito')
s= Service('C:/Users/Diego/Desktop/Trabajo_Final_LP2/chromedriver.exe')   # Se utiliza comando Service() porque arrojaba error
                                                                          # deprecated .... iperkenel.
driver = webdriver.Chrome(service=s,options = options)

# Se asigna la pagina web a scrapear
driver.get("https://www.tottus.com.pe/") 

# Selecciona y escribe el producto en el buscador Tottus 
try:
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#catalystSearchBar'))).click()
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input#inputSearchBar'))).send_keys(producto)
    #sleep(1)
    WebDriverWait(driver, 2).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.jsx-2851002401 searchIcon'.replace(' ','.')))).click()
except:
    WebDriverWait(driver, 2).until(
            EC.element_to_be_clickable((By.CSS_SELECTOR,'input.jsx-3290144217 desktopSearchBar'.replace(' ','.')))).send_keys(producto)
    WebDriverWait(driver, 2).until(
        EC.element_to_be_clickable((By.CSS_SELECTOR,'button.jsx-3290144217 searchIcon'.replace(' ','.')))).click()


datos3=[]

while True:
    WebDriverWait(driver, 10).until(
        EC.presence_of_all_elements_located((By.XPATH,'//li[@class="product"]')))
    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")    
    sleep(1)

    elementos=driver.find_elements(By.XPATH,'//li[@class="product"]')
    for elem in elementos:
        saco=[]
        try:
            nombre= elem.find_element("xpath",'.//h2[@class="jsx-369422875 name title mini"]').text
            precio= elem.find_element("xpath",'.//span[@class="list price medium cmrPrice "]').text
            cantidad= elem.find_element("xpath",'.//h3[@class="jsx-369422875 extra text descriptive"]').text
            print(nombre)
            print(precio)
            print(cantidad)
            saco.append(nombre)
            saco.append(precio)
            saco.append(cantidad)
            datos3.append(saco)
        except:
            precio = 'NO DISPONIBLE'
            producto = 'NO DISPONIBLE'

    driver.execute_script("window.scrollBy(0, -800);")
    sleep(1)
    try:
        WebDriverWait(driver, 1).until(
            EC.element_to_be_clickable((By.XPATH,'//li[@class="next"]'))).click()
        sleep(2)
    except:
        break
# Out:
# KIWICHA AVENA 3 OSITOS 270 GR
# s/ 5.6 UN
# 3-OSITOS - BOLSA 270 GR
# AVENA CON CEREALES ANDINOS 3 OSITOS 270 GR
# s/ 5.6 UN
# 3-OSITOS - BOLSA 270 GR
# KIWICHA AVENA 3 OSITOS 170 GR
# s/ 3.6 UN
# 3-OSITOS - BOLSA 170 GR
# AVENA GRANO DE ORO 370 GR
# s/ 4.2 UN
# GRANO-DE-ORO - BOLSA 370 GR
# BEBIDA VEGETAL ORGÁNICA AVENA TOTTUS LIFE 1 LT
# s/ 9.9 UN
# TOTTUS-LIFE - UNIDAD
# AVENA CON CHÍA GRANO DE ORO 170 GR
# s/ 2.9 UN
# GRANO-DE-ORO
# QUINUA AVENA GRANO DE ORO 370 GR
# s/ 4.9 UN
# GRANO-DE-ORO - BOLSA 370 GR
# AVENA CON CHÍA EN HOJUELAS GRANO DE ORO 370 GR
# s/ 4.9 UN
# GRANO-DE-ORO - BOLSA 370 GR
# AVENA HOJUELAS PRECOCIDAS TOTTUS 1KG
# s/ 9.9 UN
# TOTTUS - BOLSA 1 KG
# HOJUELAS PRECOCIDAS DE AVENA CON MACA GRANO DE ORO 370 GR
# s/ 4.9 UN
# GRANO-DE-ORO - BOLSA 370 GR
# HOJUELAS DE KIWICHA MOLICUSCO 200 GR
# s/ 7.28 UN
# MOLICUSCO - UNIDAD
# HOJUELAS DE QUINUA MOLICUSCO 200 GR
# s/ 9.25 UN
# MOLICUSCO - UNIDAD
# AVENA INSTANTÁNEA TOTTUS 500 GR
# s/ 8 UN
# TOTTUS - BOLSA 500 GR
# AVENA CHÍA EN HOJUELAS TOTTUS 380 GR
# s/ 4 UN
# TOTTUS - 380 GR
# AVENA PREMIUM 3 OSITOS PRECOCIDA 900 GR
# s/ 11.9 UN
# 3-OSITOS - 900 GR
# AVENA MIX SUPERFOOD HUELLA VERDE 600 GR
# s/ 26.9 UN
# HUELLA-VERDE - EMPAQUE 600 GR
# AVENA MIX THE SKINNY MOOD HUELLA VERDE 600 GR
# s/ 26.9 UN
# HUELLA-VERDE - - 600 GR
# BEBIDA AVENA NATURES HEART SIN AZÚCAR ANADIDA 946 ML
# s/ 12.9 UN
# NATURES-HEART - CAJA 946 ML
# AVENA 7 SEMILLAS PROTEÍNA NATURANDES 240 GR
# s/ 9.6 UN
# NATURANDES - DOYPACK 240 GR
# AVENA 7 SEMILLAS ENERGÍA NATURANDES 240 GR
# s/ 9.6 UN
# NATURANDES - DOYPACK 240 GR
# HOJUELAS PRECOCIDAS DE AVENA GRANO DE ORO 1 KG
# s/ 10.5 UN
# GRANO-DE-ORO - BOLSA 1 KG
# CEREAL EN CUADRADITOS DE AVENA TOTTUS 370 GR
# s/ 8.9 UN
# TOTTUS - CAJA 320 GR
# AVENA HOJUELAS GRUESAS GRANO DE ORO 900 GR
# s/ 16.5 UN
# GRANO-DE-ORO - POTE 900 GR
# HOJUELAS DE AVENA QUAKER QUICK 1.19 KG
# s/ 27 UN
# QUAKER - UNIDAD
# CEREAL FROOT LOOPS KELLOGGS 370 GR
# s/ 19.6 UN
# KELLOGGS - CAJA 370 GR
# AVENA 7 SEMILLAS FIBRA NATURANDES 240 GR
# s/ 9.6 UN
# NATURANDES - DOYPACK 240 GR
# AVENA EN HOJUELAS PRECOCIDA TOTTUS 380 GR
# s/ 4 UN
# TOTTUS - BOLSA 380 GR
# AVENA PRECOCIDA 3 OSITOS PREMIUM 300 GR
# s/ 5.5 UN
# 3-OSITOS - BOLSA 300 GR
# CEREAL MELI MAÍZ TRIGO, AVENA Y MIEL ANGEL 170 GR
# s/ 7.7 UN
# ANGEL - BOLSA 170 GR
# CEREAL ANGEL DE MAÍZ, TRIGO Y MIEL 420 GR
# s/ 12 UN
# ANGEL - BOLSA 420 GR
# QUINUA AVENA 3 OSITOS 270 GR
# s/ 5.6 UN
# 3-OSITOS - BOLSA 270 GR
# QUINUA AVENA TOTTUS 380 GR
# s/ 4 UN
# TOTTUS - BOLSA 380 GR
# AVENA TRADICIONAL QUAKER 900 GR
# s/ 15.7 UN
# QUAKER - PAQUETE
# MACA AVENA 3 OSITOS 270 GR
# s/ 5.6 UN
# 3-OSITOS - BOLSA 270 GR
# GALLETA DE AVENA CHOCOLATE
# s/ 4.5 UN
# TOTTUS - BOLSA 135 GR
# AVENA MACA QUAKER 360 GR
# s/ 8.6 UN
# QUAKER - BOLSA 360 GR
# AVENA QUINUA QUAKER 360 GR
# s/ 8.5 UN
# QUAKER - BOLSA 360 GR
# KIWICHA AVENA TOTTUS 380 GR
# s/ 4 UN
# TOTTUS - BOLSA 380 GR
# MACA AVENA 3 OSITOS 170 GR
# s/ 3.6 UN
# 3-OSITOS - BOLSA 170 GR
# QUINUA AVENA 3 OSITOS 170 GR
# s/ 3.6 UN
# 3-OSITOS - BOLSA 170 GR
# AVENA MULTISEMILLAS TOTTUS LIFE 45 GR
# s/ 4.9 UN
# TOTTUS-LIFE - ENVASE 45 GR
# PAN MULTISEMILLAS AVENA UNIÓN 540 GR
# s/ 11.4 UN
# UNION - BOLSA 540 GR
# PRE MEZCLA GALLETAS DE AVENA
# s/ 6 UN
# TOTTUS - BOLSA 310 GR
# AVENA MIX AGUAYMANTO LINAZA 500 GR
# s/ 22.5 UN
# MAMALAMA - UNIDAD
# AVENA EN VASO INSTANTÁNEA CON CHOCOLATE TOTTUS LIFE 45 GR
# s/ 4.9 UN
# TOTTUS-LIFE - ENVASE 45 GR
# CUPS AVENA MANZANA Y CANELA TOTTUS LIFE 45 GR
# s/ 4.9 UN
# TOTTUS-LIFE - ENVASE 45 GR
# AVENA CACAO NIBS OATMEAL ENERGY 250 GR
# s/ 12 UN
# NUTRI-CO - UNIDAD
# HOJUELAS DE AVENA MUSLI DE MANZANA TOTTUS 375 GR
# s/ 8.9 UN
# TOTTUS - CAJA 375 GR
# AVENA EN VASO INSTANTÁNEA CON FRUTOS ROJOS TOTTUS LIFE 45 GR
# s/ 4.9 UN
# TOTTUS-LIFE - ENVASE 45 GR
# JABON ADULTO BARRA AVENA
# s/ 8.7 UN
# JOHNSONS-ADULTO - PACK 3 UN - 110 GR
# HOJUELAS DE AVENA GLUTEN FREE NATURES PATH 510 GR
# s/ 24.9 UN
# NATURES-PATH - UNIDAD
# HOJUELAS AVENA BOBS RED MILL SIN GLUTEN 907 GR
# s/ 44.9 UN
# BOBS-RED-MILL - UNIDAD
# GRANOLA AVENA MANZANA PECANAS Y CANELA CROSOY 380 GR
# s/ 13.3 UN
# CROSOY - UNIDAD
# AVENA MIX CANELA & BERRIES AMARU SUPERFOODS 400 GR
# s/ 24 UN
# AMARU-SUPERFOODS - UNIDAD
# AVENA BLUEBERRRY OATMEAL FIBER 250 GR
# s/ 12 UN
# NUTRI-CO - UNIDAD
# AVENA CON MANZANA OATMEAL PROTEIN 250 GR
# s/ 12 UN
# NUTRI-CO - UNIDAD
# AVENA MIX CACAO MACA 500 GR
# s/ 22.5 UN
# MAMALAMA - UNIDAD
# AVENA MIX CHOCOPLÁTANO AMARU 400 GR
# s/ 24 UN
# AMARU-SUPERFOODS - UNIDAD
# JABÓN ADULTO ORIGINAL AVENA
# s/ 16.9 UN
# JOHNSONS-ADULTO - UN
# JABÓN DE TOCADOR AVENA Y AZÚCAR
# s/ 8.5 UN
# PALMOLIVE - PACK 3 UN -120 GR
# JABÓN ANTIBACTERIAL AVENA
# s/ 9.5 UN
# PROTEX - PACK 3 UN -110 GR
# AVENA MIX LUCUMANGO AMARU SUPERFOODS 400 GR
# s/ 24 UN
# AMARU-SUPERFOODS - UNIDAD
# JABÓN LÍQUIDO AVENA FRASCO
# s/ 8.5 UN
# PROTEX - ENVASE 220 ML
# JABÓN LÍQUIDO AVENA DOYPACK
# s/ 10.9 UN
# PROTEX - DOYPACK 500 ML
# PAN DE LA CASA CON AVENA TOTTUS 510 GR
# s/ 11.9 UN
# TOTTUS - PAQUETE 500 GR
# JABÓN DE TOCADOR AVENA Y AZÚCAR
# s/ 19.9 UN
# PALMOLIVE - PACK 6 UN -120 GR
# CEREAL BAR DE ARÁNDANOS COSTA 8 UNIDADES
# s/ 4.49 UN
# COSTA - CAJA 8 UNDS
# CEREAL CHEERIOS GENERAL 340 GR
# s/ 39.5 UN
# GENERAL-MILLS - CAJA 340 GR
# GALLETAS MANAZANA TOTTUS KIDS 50 GR
# s/ 10.9 UN
# TOTTUS-KIDS - ENVASE 50 GR
# SALVAVENA GRANO DE ORO 800 GR
# s/ 17.5 UN
# GRANO-DE-ORO - POTE 800 GR
# SALVA MIX PLUS GRANO DE ORO 850 GR
# s/ 22.5 UN
# GRANO-DE-ORO - POTE 253 GR
# SALVATRIGO GRANO DE ORO 350 GR
# s/ 11.9 UN
# GRANO-DE-ORO - POTE 350 GR
# GALLETAS PLATANO TOTTUS KIDS 50 GR
# s/ 10.9 UN
# TOTTUS-KIDS - ENVASE 50 GR
# GRANOLA CON KIWICHA Y CHIA CROSOY 380 GR
# s/ 12.8 UN
# CROSOY - BOLSA 380 GR
# GALLETAS FRESA TOTTUS KIDS 50 GR
# s/ 10.9 UN
# TOTTUS-KIDS - ENVASE 50 GR
# HOJUELAS DE MAÍZ SABOR A CHOCOLATE TOTTUS 400 GR
# s/ 9.9 UN
# TOTTUS - 400 GR
# CEREAL ARITOS SABOR FRUTAL TOTTUS 340 GR
# s/ 9.9 UN
# TOTTUS - 340 GR
# GRANOLA TROCITOS DE FRESAS Y MAÍZ GLASEADO 350 GR
# s/ 9.9 UN
# TOTTUS - PAQUETE 350 GR
# GRANOLA CON CEREZA Y CHOCOLATE BLANCO TOTTUS 350 GR
# s/ 9.9 UN
# TOTTUS - CAJA 350 GR
# GRANOLA CON FRUTOS DEL BOSQUE TOTTUS 350 GR
# s/ 3.9 UN
# TOTTUS - CAJA 350 GR
# CEREAL BAR MANZANA Y CANELA COSTA 8 UNIDADES
# s/ 4.49 UN
# COSTA - CAJA 8 UNDS
# GRANOLA MUSLI DE FRUTOS SECOS TOTTUS 375 GR
# s/ 8.9 UN
# TOTTUS - CAJA 375 GR
# GALLETAS DE BEBÉ CAMOTE Y ZANAHORIA 50G
# s/ 10.9 UN
# TOTTUS-BEBE - UNIDAD
# GALLETAS DE MANZANA PARA BEBÉ TOTTUS 50 GR
# s/ 10.9 UN
# TOTTUS-BEBE - UNIDAD
# GALLETAS PARA BEBÉ TOTTUS 50 GR
# s/ 10.9 UN
# TOTTUS-BEBE - UNIDAD
# GALLETAS PARA BEBÉ DE PLÁTANO TOTTUS 50 GR
# s/ 10.9 UN
# TOTTUS-BEBE - UNIDAD
# GRANOLA CON TROZOS DE CHOCOLATE TOTTUS 350 GR
# s/ 3.9 UN
# TOTTUS - CAJA 350 GR
# GRANOLA CON PASAS Y ALMENDRAS TOTTUS 350 GR
# s/ 3.9 UN
# TOTTUS - CAJA 350 GR
# BOLITAS DE CEREALES SABOR CHOCOLATE TOTTUS 500 GR
# s/ 9.9 UN
# TOTTUS - CAJA 500 GR
# HOJUELAS DE QUINUA PRECOCIDA TOTTUS LIFE 200 GR
# s/ 14.9 UN
# TOTTUS-LIFE - CAJA 200 GR
# HOJUELA DE QUINUA PRECOCIDA ORGÁNICO TOTTUS LLIFE 200 GR
# s/ 14.9 UN
# TOTTUS-LIFE - CAJA 200 GR
# CEREAL DE MAÍZ CORN FLAKES TOTTUS 500 GR
# s/ 9.9 UN
# TOTTUS - 500 GR
# BARRA CEREAL FRUTOS ROJOS TOTTUS 8 UNIDADES 20 GR
# s/ 2.9 UN
# TOTTUS - 8 UNIDADES
# BARRA CEREAL MIEL Y LECHE TOTTUS 8 UNIDADES
# s/ 2.9 UN
# TOTTUS - PAQUETE 8 UN
# BARRA CEREAL CHOCOLATE TOTTUS 8 UNIDADES
# s/ 2.9 UN
# TOTTUS - 8 UNIDADES
# HOJUELAS DE MAÍZ AZUCARADAS TOTTUS 500 GR
# s/ 9.9 UN
# TOTTUS - 500 GR
# MULTIGRANO CON FRUTOS ROJOS TOTTUS 300 GR
# s/ 8.9 UN
# TOTTUS - CAJA 300 GR
# HOJUELAS DE CEREAL MULTIGRANO CON CHOCOLATE TOTTUS 300 GR
# s/ 3.9 UN
# TOTTUS - CAJA 300 GR
# QUINUA POP ORGÁNICO TOTTUS LIFE 150 GR
# s/ 14.9 UN
# TOTTUS-LIFE - CAJA 150 GR
# CEREAL DE TRIGO INTEGRAL, ARROZ Y QUINUA TOTTUS 350 GR
# s/ 8.9 UN
# TOTTUS - CAJA 350 GR
# QUINUA POP CON CHOCOLATE ORGÁNICO TOTTUS 15 GR
# s/ 14.9 UN
# TOTTUS-LIFE - CAJA 150 GR
# MULTIGRANO REGULAR TOTTUS 375 GR
# s/ 8.9 UN
# TOTTUS - CAJA 375 GR
# JABON LIQUIDO PROTEX AVENA ANTIBACTERIAL 760 ML
# s/ 19.9 UN
# PROTEX - ENVASE 760 ML
# JABON LIQUIDO PROTEX ANTIBACTERIAL BALANCE SALUD DOYP 800 ML
# s/ 15.9 UN
# PROTEX - ENVASE 800 ML
# JABON ANTIBACTERIAL AVENA 75 GR
# s/ 8.5 UN
# NEKO - PACK 4 UN
# JABÓN LÍQUIDO ANTIBACTERIAL CON AVENA Y MIEL
# s/ 10.4 UN
# BACTERION - FRASCO 300 ML
# JABON LIQUIDO ANTIBACTERIAL AVENA & MIEL
# s/ 8.9 UN
# TOTTUS - FRASCO 400 GR
# JABON DE TOCADOR AVENA & MIEL 125 GR
# s/ 7.5 UN
# TOTTUS - PACK 3 UN
# JABÓN LÍQUIDO ANTIBACTERIAL AVENA Y MIEL
# s/ 13.2 UN
# BACTERION - DOYPACK 1 LT
# SIXPACK NIVEA SHOWER & SOAP JABON AVENA
# s/ 17.9 UN
# NIVEA - SIX PACK
# DOYPACK JABÓN LIQUIDO AVENA PRECIO UNO 1 LT
# s/ 9.9 UN
# PRECIO-UNO - ENVASE X 1 L
# LOCIÓN CORPORAL NIVEA NATURALLY GOOD AVENA NATURAL 350 ML
# s/ 24.72 UN
# NIVEA - NIVEA
# TRIPACK JABÓN EN BARRA BABY AVENA JOHNSON'S BABY 330 GR
# s/ 12.9 UN
# JOHNSONS-BABY - ENVASE 330 GR
# CREMA LÍQUIDA AVENA JOHNSON'S BABY 800 ML
# s/ 42.5 UN
# JOHNSONS-BABY - ENVASE 800 ML
# BAÑO LIQUIDO AVENA JOHNSON'S BABY 400 ML
# s/ 25.2 UN
# JOHNSONS-BABY - ENVASE 400 ML
# JABON DE AVENA CON CREMA HUMECTANTE
# s/ 3.19 UN
# DR-ZAIDMAN - BARRA 80 GR
# CREMA LÍQUIDA AVENA JOHNSON'S BABY 400 ML
# s/ 31.7 UN
# JOHNSONS-BABY - ENVASE 400 ML
# ACONDICIONADOR AVENA AMMENS 400 ML
# s/ 19.5 UN
# AMMENS - DOYPACK 400 ML
# CREMA CORPORAL CON LECHE HIDRATANTE Y AVENA
# s/ 32 UN
# INSTITUTO-ESPANOL - ENVASE 500 ML
# HOJUELAS DE AVENA ORGÁNICA BOB'S RED MILL SIN GLUTEN 907 GR
# s/ 48.4 UN
# BOBS-RED-MILL - UNIDAD

# %%
# LIMPIEZA Y ESTRUCTURACIÓN DE DATOS DESCARGADOS (Tottus)

# Se importan librerias
import re
import pandas as pd

total3=[]

for i in datos3:
    saco1=[]   # nombre-precio-cantidad
    saco1.append('Tottus')
    for e in i:
        if e==i[0]:
            saco1.append(e)
        if e==i[1]:
            e=e.split()
            for q in e:
                z=re.findall('\d.+',q)
                z1=re.findall('\d+',q)
                if len(z)>0: 
                    saco1.append(z[0])
                elif len(z1)>0:
                    saco1.append(z1[0])
        if e==i[2]:
            saco1.append(e)

    total3.append(saco1)        

# Se crea dataframe con datos ya estructurados con las columnas Nombre-Precio(S/.)-Cantidad

columnas=['Local','Nombre','Precio (S/.)','Cantidad']
Tottus=pd.DataFrame(data=total3,columns=columnas)           
Tottus
# Out:
#       Local                                             Nombre Precio (S/.)  \
# 0    Tottus                      KIWICHA AVENA 3 OSITOS 270 GR          5.6
# 1    Tottus         AVENA CON CEREALES ANDINOS 3 OSITOS 270 GR          5.6
# 2    Tottus                      KIWICHA AVENA 3 OSITOS 170 GR          3.6
# 3    Tottus                          AVENA GRANO DE ORO 370 GR          4.2
# 4    Tottus     BEBIDA VEGETAL ORGÁNICA AVENA TOTTUS LIFE 1 LT          9.9
# ..      ...                                                ...          ...
# 115  Tottus                JABON DE AVENA CON CREMA HUMECTANTE         3.19
# 116  Tottus          CREMA LÍQUIDA AVENA JOHNSON'S BABY 400 ML         31.7
# 117  Tottus                 ACONDICIONADOR AVENA AMMENS 400 ML         19.5
# 118  Tottus        CREMA CORPORAL CON LECHE HIDRATANTE Y AVENA           32
# 119  Tottus  HOJUELAS DE AVENA ORGÁNICA BOB'S RED MILL SIN ...         48.4
#
#                               Cantidad
# 0              3-OSITOS - BOLSA 270 GR
# 1              3-OSITOS - BOLSA 270 GR
# 2              3-OSITOS - BOLSA 170 GR
# 3          GRANO-DE-ORO - BOLSA 370 GR
# 4                 TOTTUS-LIFE - UNIDAD
# ..                                 ...
# 115           DR-ZAIDMAN - BARRA 80 GR
# 116      JOHNSONS-BABY - ENVASE 400 ML
# 117            AMMENS - DOYPACK 400 ML
# 118  INSTITUTO-ESPANOL - ENVASE 500 ML
# 119             BOBS-RED-MILL - UNIDAD
#
# [120 rows x 4 columns]
